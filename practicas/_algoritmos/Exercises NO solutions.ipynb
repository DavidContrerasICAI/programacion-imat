# %% [markdown]
# ## MISSING NUMBER
# Write a function to find the missing number in a given integer array of 1 to n.
# The function takes to parameter the array and the number of elements that needs to be in array.
# For example if we want to find missing number from 1 to 6 the second parameter will be 6. The array might not be sorted!
#
# Note: There are no duplicates in the list.

# %% [markdown]
# ## TWO SUM
# Given an array of integers nums and an integer target, return the indices of the two numbers that add up to the target.
# Each input would have exactly one solution, and you may not use the same element twice.

# %% [markdown]
# ## AX PRODUCT
# Find the maximum product of two integers in an array where all elements are positive.

# %% [markdown]
# ## REMOVE DUPLICATES
# Write a function to remove the duplicate numbers on given integer array/list.

# %% [markdown]
# ## PAIR_SUM
# Write a function to find all pairs of an integer array whose sum is equal to a given number.
#
# Do not consider commutative pairs.

# %% [markdown]
# ## CONTAINS_DUPLICATE:
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example :
# ```
#     Input: nums = [1,2,3,1]
#     Output: True
# ```

# %% [markdown]
# ## Rotate Matrix/ Image - LeetCode 48
# You are given an n x n 2D matrix representing an image, rotate the image by 90 degrees (clockwise).
# You have to rotate the image in-place, which means you have to modify the input 2D matrix directly.
# DO NOT allocate another 2D matrix and do the rotation.
#
# This envolves transpose the matrix and then reverse each row
#
# Example:
# Given an array arr[] of size N. The task is to find the sum of the contiguous subarray within a arr[] with the largest sum.

# %% [markdown]
# ## FIND SINGULAR NUMBERS
# Write a function called find_singular_nums that identifies and returns the indices of "singular numbers" in a list of integers.
# A "singular number" is an element in a vector whose value is equal to the arithmetic mean of all previous elements in the vector.
# The first element of the vector cannot be singular since there are no previous elements to compute the average.
#
#     -Find first repeating character of an english string (maximum 26 different characters)
#     -Given a string in english, return the first repeating character of the string
#     -It is forbidden to use any auxiliar structures except for lists
#     -Hint: ord(character) returns the number representing the unicode code of a specified character.
#
#     Returns the first repeating character or None otherwise

# %% [markdown]
# ## Find the index
#     Given a list of integers, find the index where the sum of integers in the left is equal to the sum of integers in the right. If no index is found, return -1
#     Note: the index is not taken into account in any of the sums
