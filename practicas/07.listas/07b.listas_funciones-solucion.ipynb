# %% [markdown]
# # Práctica 7b. Listas - Representación de funciones

# %% [markdown]
# ## Enunciado de la práctica
#
# Desarrollar un programa que permita representar gráficamente dos funciones matemáticas.
#
# $f(x) = x^2 - 3*x + 5$
#
# $g(x) = -5*x^2 + 4*x + 25$
#
# Los distintos puntos a obtener de las funciones se almacenarán en listas y se obtendrán en el rango del eje X [-5, +5] cada  0.25, calculando en total 41 puntos.
#
# Será obligatorio trabajar con la función range() y todos los bucles se generarán con estructuras **for in**. Estará prohibido trabajar con **while**.
#
# Para representar las funciones se trabajará con la librería **matplotlib** de la siguiente forma:
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot(eje_x, f_x)  # eje_x y f_x son listas.
# plt.plot(eje_x, g_x)  # eje_x y g_x son listas.
# plt.show()
# ```
#
# ### Salida
#
# Se mostrará la salida generada por el método show() y la tabla de puntos de la función $f(x)$.

# %% [markdown]
# ![07.listas_funciones.jpg](attachment:07.listas_funciones.jpg)

# %% [markdown]
# ## Solución

# %%
import matplotlib.pyplot as plt

X_MIN = -5
X_MAX = 5

eje_x = []
f_x = []
g_x = []

for x in range(X_MIN, X_MAX):
    eje_x.append(x)
    for ticks in range(1, 4):
        eje_x.append(x + ticks/4)

eje_x.append(X_MAX)

for x in eje_x:
    f_x.append(x**2 - 3*x + 5)
         
for x in eje_x:
    g_x.append(-5*x**2 + 4*x + 25)

plt.plot(eje_x, f_x)
plt.plot(eje_x, g_x)
plt.show()

print("Tabla de puntos de la función f(x): (x, y)")

cont = 0
for x in eje_x:
    print(f"({x}, {f_x[cont]})")
    cont += 1
# Out:
# Tabla de puntos de la función f(x): (x, y)
# (-5, 45)
# (-4.75, 41.8125)
# (-4.5, 38.75)
# (-4.25, 35.8125)
# (-4, 33)
# (-3.75, 30.3125)
# (-3.5, 27.75)
# (-3.25, 25.3125)
# (-3, 23)
# (-2.75, 20.8125)
# (-2.5, 18.75)
# (-2.25, 16.8125)
# (-2, 15)
# (-1.75, 13.3125)
# (-1.5, 11.75)
# (-1.25, 10.3125)
# (-1, 9)
# (-0.75, 7.8125)
# (-0.5, 6.75)
# (-0.25, 5.8125)
# (0, 5)
# (0.25, 4.3125)
# (0.5, 3.75)
# (0.75, 3.3125)
# (1, 3)
# (1.25, 2.8125)
# (1.5, 2.75)
# (1.75, 2.8125)
# (2, 3)
# (2.25, 3.3125)
# (2.5, 3.75)
# (2.75, 4.3125)
# (3, 5)
# (3.25, 5.8125)
# (3.5, 6.75)
# (3.75, 7.8125)
# (4, 9)
# (4.25, 10.3125)
# (4.5, 11.75)
# (4.75, 13.3125)
# (5, 15)
