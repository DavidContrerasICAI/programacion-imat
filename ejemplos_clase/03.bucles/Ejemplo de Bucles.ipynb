# %%
contador2 = 10
numero = 1
while numero < 10:
    contador2 = contador2 - numero
    print("valor de la variable contador2:", contador2)
    numero = numero + 1
    print("numero: ", numero)
    print()
# Out:
# valor de la variable contador2: 9
# numero:  2
#
# valor de la variable contador2: 7
# numero:  3
#
# valor de la variable contador2: 4
# numero:  4
#
# valor de la variable contador2: 0
# numero:  5
#
# valor de la variable contador2: -5
# numero:  6
#
# valor de la variable contador2: -11
# numero:  7
#
# valor de la variable contador2: -18
# numero:  8
#
# valor de la variable contador2: -26
# numero:  9
#
# valor de la variable contador2: -35
# numero:  10

# %%
a = 5
b = "hola"
print(a, b, 2, 2, 2)
# Out:
# 5 hola 2 2 2

# %%
2 + 2 + 4
# Out:
# 8

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !wmic cpu get name, numberofcores, maxclockspeed
# Out:
# MaxClockSpeed  Name                                            NumberOfCores
#
# 2995           11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz  4

# %%
a = 2
a = 2

# %%
a = 2
a == 2
# Out:
# True

# %%
while = 1
# Out:
#   File "C:\Users\davidcb\AppData\Local\Temp\ipykernel_15372\544408828.py", line 1
#     while = 1
#           ^
# SyntaxError: invalid syntax

# %%
2**10
# Out:
# 1024

# %%
5%2
# Out:
# 1

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
mayor_edad = True

# %%
b = 12
print(1+b)
type(b)
b = "hola"
type(b)
b = mayor_edad == True
print(1+b)
b
# Out:
# 13
# 2
# True

# %%
b = "hola"
type(b)
print(1+b)
b = mayor_edad == True
print(1+b)
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15372\4162851366.py in <module>
#       1 b = "hola"
#       2 type(b)
# ----> 3 print(1+b)
#       4 b = mayor_edad == True
#       5 print(1+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
condicion = mayor_edad == True
type(condicion)
# Out:
# bool

# %%
type(mayor_edad)
# Out:
# bool

# %%
if mayor_edad == True:
    print("Es mayor de edad")
# Out:
# Es mayor de edad

# %%
type("qwqw", 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15372\2489248357.py in <module>
# ----> 1 type("qwqw", 1)
#
# TypeError: type() takes 1 or 3 arguments

# %%
"""
Descricpión de lo que hace el programa

print(2+4)

David
Created: 17/09/2024
Modified: 19/09/2024
asddsa
ds
fsd
fsd
fsd
"""
print(1)    # Imprime un 1
b = 2
h = 3
print("*"*20)
print("El área es:", b*h/2 + 3)    # Imprime el área
print("***************************")
# Out:
# 1
# ********************
# El área es: 6.0
# ***************************

# %%
b_str = input("Base: ")
b = float(b_str)
h_str = input("Altura: ")
h = float(h_str)
area = b*h/2
print("El área del triángulo con base", b, "y altura", h, "es", area)
# Out:
# Base: 1
# Altura: 2
# El área del triángulo con base 1.0 y altura 2.0 es 1.0

# %%
2**3-1
# Out:
# 7

# %%
2**64-1
# Out:
# 18446744073709551615

# %%
2**8-1
# Out:
# 255
