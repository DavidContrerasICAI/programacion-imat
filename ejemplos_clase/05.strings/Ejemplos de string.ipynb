# %% [markdown]
# # Ejemplos de strings

# %%
"A"
# Out:
# 'A'

# %%
ord("A")
# Out:
# 65

# %%
hex(65)
# Out:
# '0x41'

# %%
"\u0041"
# Out:
# 'A'

# %%
"\U0001F600"
# Out:
# '😀'

# %%
fire = "🔥"

# %%
fire
# Out:
# '🔥'

# %%
a = "Me \t\tllaman \nEl kuki\n"
print(a)
# Out:
# Me 		llaman
# El kuki

# %%
a = "Me llaman \"El kuki\""
print(a)
# Out:
# Me llaman "El kuki"

# %%
a = "C\\ Alberto Aguilera, 25"
print(a)
# Out:
# C\ Alberto Aguilera, 25

# %%
a = "A"
b = "B"
print(a + b)
# Out:
# AB

# %%
s = a + b
print(s)
# Out:
# AB

# %%
print(a, b, "hola", 45)
# Out:
# A B hola 45

# %%
s = a + b + "hola"
print(s)
# Out:
# ABhola

# %%
print(a + b + "hola")
# Out:
# ABhola

# %%
print(a + b + "hola" + str(45))
# Out:
# ABhola45

# %%
str(45)
# Out:
# '45'

# %%
int("45")
# Out:
# 45

# %%
"=" * 30
# Out:
# '=============================='

# %%
"abc" * 5
# Out:
# 'abcabcabcabcabc'

# %%
a = 4
b = 5
print("El valor a es " + str(a) + " y el valor b es " + str(b) + ", por lo que el resultado final será " + str(a + b))
# Out:
# El valor a es 4 y el valor b es 5, por lo que el resultado final será 9

# %%
f"Hola{a}yb{b}"
# Out:
# 'Hola4yb5'

# %%
"Hola"
# Out:
# 'Hola'

# %%
{HOLA}

# %%
a = 4
b = 5
print(f"El valor a es {a} y el valor b es {b}, por lo que el resultado final será {a + b}")
# Out:
# El valor a es 4 y el valor b es 5, por lo que el resultado final será 9

# %%
s = """sd ds TODO EN DIFERENTES LÍNEAS - PREFORMATEADO kfh ksdhfksdh fksdjfhsd jkfgsd 
fnkjs d fkjhsdfhsdjkfh sdfhk sdfdskjfhkjsdfhjsd 
kfh sdkfhskdjfhjs djkfsdkjfhsdkfh 
skd"""

# %%
print(s)
# Out:
# sd ds TODO EN DIFERENTES LÍNEAS - PREFORMATEADO kfh ksdhfksdh fksdjfhsd jkfgsd
# fnkjs d fkjhsdfhsdjkfh sdfhk sdfdskjfhkjsdfhjsd
# kfh sdkfhskdjfhjs djkfsdkjfhsdkfh
# skd

# %%
s = "sd dskfh TODO EN LA MISMA LÍNEA fksdjfhsd jkfgsd kj kjgkj  kk h kjh kjh kj kj \
sfnkjs d fkjhsdfhsdjkfh sdfhk sdfdskjfhkjsdfhjsd \
kfh sdkfhskdjfhjs djkfsdkjfhsdkfh \
skd"

# %%
print(s)
# Out:
# sd dskfh TODO EN LA MISMA LÍNEA fksdjfhsd jkfgsd kj kjgkj  kk h kjh kjh kj kj sfnkjs d fkjhsdfhsdjkfh sdfhk sdfdskjfhkjsdfhjsd kfh sdkfhskdjfhjs djkfsdkjfhsdkfh skd

# %% [markdown]
# # Índices

# %%
nombre = "Luis García Carrión"

# %%
matricula = "1234BCS"

# %%
mensaje = "Hola es de dia"

# %%
nombre
# Out:
# 'Luis García Carrión'

# %%
len(nombre)
# Out:
# 19

# %%
nombre[4]
# Out:
# ' '

# %%
nombre[18]
# Out:
# 'n'

# %%
contador = 0
while contador < len(nombre):
    if nombre[contador] == " ":
        print("")
    else:
        if nombre[contador] == "a": 
            print("X", end = "")
        else:
            print(nombre[contador], end = "")
    contador = contador + 1
# Out:
# Luis
# GXrcíX
# CXrrión

# %%
nombre = "Luis García Carrión"
nombre_modificado = ""
contador = 0
while contador < len(nombre):
    caracter = nombre[contador]
    if caracter == " ":
        nombre_modificado = nombre_modificado + "\n"
    else:
        if caracter == "a": 
            nombre_modificado = nombre_modificado + "X"
        else:
            nombre_modificado = nombre_modificado + caracter
    contador = contador + 1

# %%
print(nombre_modificado)
# Out:
# Luis
# GXrcíX
# CXrrión

# %%
indice = len(nombre) - 1
while indice >= 0:
    print(nombre[indice], end = "")
    indice = indice - 1
# Out:
# nóirraC aícraG siuL

# %%
i = 65
s = ""
while i < 71:
    s = s + chr(i)
    i = i + 1

# %%
print(s)
# Out:
# ABCDEF

# %%
contador = 1
while contador < len(nombre):
    print(nombre[contador], end = "")
    contador = contador + 2
# Out:
# usGrí aró

# %%
contador = 0
while contador < len(nombre):
    print(nombre[contador], end = "")
    contador = contador + 2

# %%
i = 7
i += 1
i
# Out:
# 8

# %%
s = "abc"
s += "d"
s
# Out:
# 'abcd'

# %%
contador = 0
while contador < len(nombre):
    print(nombre[contador], end = "")
    contador += 2
# Out:
# Li acaCrin

# %%
nombre
# Out:
# 'Luis García Carrión'

# %%
nombre[3]
# Out:
# 's'

# %% [markdown]
# ### Slicing

# %%
nombre[0:7:2]
# Out:
# 'Li a'

# %%
nombre[0:4]
# Out:
# 'Luis'

# %%
nombre[0:4]
# Out:
# 'Luis'

# %%
nombre[:4]
# Out:
# 'Luis'

# %%
nombre[4:]
# Out:
# ' García Carrión'

# %%
nombre[0:3:1]
# Out:
# 'Lui'

# %%
nombre[:3]
# Out:
# 'Lui'

# %%
nombre[len(nombre)-1]
# Out:
# 'n'

# %%
emojis = "😀😃😄😁😆😅🤣😂🙂🙃🫠😉😊😇🥰😍🤩😘😗☺️😚😙🥲😋😛😜🤪"
alegre = True
if alegre == True:
    print(emojis[0])
else:
    print(emojis[27])
# Out:
# 😀

# %% [markdown]
# ### Método find, por ejemplo

# %%
nombre = "Luis García Carrión"
nombre.find("a")
# Out:
# 6

# %%
nombre = "Luis García Carrión"
nombre_modificado = ""
contador = 0
encontrado = False
while contador < len(nombre):
    caracter = nombre[contador]
    if caracter == "a":
        if encontrado == False:
            print(contador)
            encontrado = True
    contador = contador + 1
# Out:
# 6
