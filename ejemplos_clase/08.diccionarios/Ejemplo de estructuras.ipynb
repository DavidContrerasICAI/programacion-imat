# %%
lista = [1, 2, 3]
tupla = (1, 2, 3)

# %%
type(lista)
# Out:
# list

# %%
type(tupla)
# Out:
# tuple

# %%
lista[0] = 99
lista
# Out:
# [99, 2, 3]

# %%
tupla[0] = 99
tupla
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\2732148714.py in <module>
# ----> 1 tupla[0] = 99
#       2 tupla
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupla[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17224\1755845087.py in <module>
# ----> 1 tupla[3]
#
# IndexError: tuple index out of range

# %%
letra = "a"
cuenta = 3

# %%
t = (letra,cuenta)

# %%
t
# Out:
# ('a', 3)

# %%
t[0]
# Out:
# 'a'

# %% [markdown]
# # Diccionarios

# %%
saldos = {}
type(saldos)
# Out:
# dict

# %%
saldos = {"luis":[100, 11, 7777, 55], "ana":[25], "miguel":[7]}

# %%
saldos
# Out:
# {'luis': [100, 11, 7777, 55], 'ana': [25], 'miguel': [7]}

# %%
saldos_fds = saldos["luis"]
saldos_fds[2]
# Out:
# 7777

# %%
saldos = {111:100, 222:25, 333:7}

# %%
saldos[111]
# Out:
# 100

# %%
saldos_dict = {111:100, 222:25, 333:7}

# %%
dineros = saldos_dict.values()

# %%
type(dineros)
# Out:
# dict_values

# %%
list(dineros)
# Out:
# [100, 25, 7, 999]

# %%
dineros
# Out:
# dict_values([100, 25, 7, 999])

# %%
sorted(dineros, reverse=True)
# Out:
# [999, 100, 25, 7]

# %%
saldos_dict[111]
# Out:
# 100

# %%
saldos_dict[444] = 999

# %%
saldos_dict
# Out:
# {111: 100, 222: 25, 333: 7, 444: 999}

# %%
coches = {"luis":"VW", "ana": "seat", "miguel": "skoda"}

# %%
coches["luis"] = "BMW"

# %%
coches
# Out:
# {'luis': 'BMW', 'ana': 'seat', 'miguel': 'skoda'}

# %%
coches.items()
# Out:
# dict_items([('luis', 'BMW'), ('ana', 'seat'), ('miguel', 'skoda')])

# %%
coches.keys()
# Out:
# dict_keys(['luis', 'ana', 'miguel'])

# %%
coches.values()
# Out:
# dict_values(['BMW', 'seat', 'skoda'])
