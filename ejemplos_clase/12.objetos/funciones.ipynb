# %%
def sumar(a:int, b:int) -> int:
    """
    Esta fudbhjkd fhdsfdsfdsfdsfdsfds

    sumar(2, 3) ---> 5

    "Luis22Madrid" --> ("LUIS", 22, "M")
    Args:


    Return:

    Raise:
    """
    return a + b    # DEvuelve el resultado de la suma

# %%
sumar(1, 4)
# Out:
# 5

# %%
sumar(a=1, b=2)
# Out:
# 3

# %%
sumar(b=2, a=1)
# Out:
# 3

# %%
def sumar(a:int, b:int, c:int = 10, d:int = 1) -> int:
    return a + b + c + d    # DEvuelve el resultado de la suma

# %%
sumar(1, 1, , 9)
# Out:
#   Cell In[33], line 1
#     sumar(1, 1, , 9)
#                 ^
# SyntaxError: invalid syntax

# %%
def crear_persona(nombre, apellidos, cp)->tuple[str, str, str]:
    return nombre, apellidos, cp

# %%
crear_persona(nombre = "luis", apellidos = "luis", 28007)
# Out:
# ('luis', 'luis', 28007)

# %%
a
# Out:
# (1, 2, 3)

# %%
def sumar(*numeros:int) -> int:
    suma = 0
    for numero in numeros:
        suma += numero 
    return suma

# %%
sumar(1, 2, 3, 6)
# Out:
# (1, 2, 3, 6)

# %%
a = 1

def f():
    global a 
    print(a)

def f2():
    global a 
    print(a)

print(a)

# %%
def f(lista):
    lista.append(1)
    print(lista)
    print(id(lista))

def f2(lista):
    lista.append(2)
    print(lista)
    print(id(lista))

lista = []
f(lista)
f2(lista)
print(lista)
print(id(lista))
# Out:
# [1]
# 2435861891456
# [1, 2]
# 2435861891456
# [1, 2]
# 2435861891456

# %%
a = 22
print(id(a))
b = 44
print(id(b))
# Out:
# 140724989148248
# 140724989148952

# %%
def f(a):
    a += 1
    return a

def f2(a):
    print(id(a))

a = 4
a = f(a)
print(a)
# Out:
# 5

# %%
dni = "22a"
try:
    dni_int = int(dni[:2])
    letra = dni[-1]
except:
    print("error")
# Out:
# error
