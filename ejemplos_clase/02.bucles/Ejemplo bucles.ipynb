# %% [markdown]
# ## Condicional

# %% [markdown]
# ![image.png](attachment:6794d758-2aed-479f-93be-76d0ce3c8216.png)

# %%
temperatura = 30
if temperatura > 25:
    print("Hace calor")
else:
    print("No hace calor")
# Out:
# Hace calor

# %% [markdown]
# ## Bucle

# %% [markdown]
# ![image.png](attachment:f983d12c-8e24-400a-95f3-358f2f104753.png)

# %%
cont = 0    # INICIALIZAMOS

while cont <= 5:    # EVALUAMOS
    print("Hola")
    cont = cont + 1    # INCREMENTAMOS EL CONTADOR
# Out:
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
