# %%
nombre = "Luis"
edad = 23
nombre = "Ana"
direccion = 'Calle del Pez, 3'

a = "23"
b = "54"

print(nombre)
# Out:
# Ana

# %%
print(edad + 2)
# Out:
# 25

# %%
print(a + b)
# Out:
# 2354

# %%
print("Luis" + "Ana")
# Out:
# LuisAna

# %%
print("Luis" + " " + "XII")
# Out:
# Luis XII

# %%
print(nombre + 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(nombre + 2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(nombre + "2")
# Out:
# Ana2

# %%
type(nombre)
# Out:
# str

# %%
type(edad)
# Out:
# int

# %%
nombre = Luis
edad = 23
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 nombre = Luis
#       2 edad = 23
#
# NameError: name 'Luis' is not defined

# %%
resultado = 23 + (56 + (34 * 4)) * 2
print(resultado)
# Out:
# 407

# %%
x = 12
y = 1

print(x + y)
# Out:
# 13

# %%
resultado = x + y 
print(resultado)
# Out:
# 13

# %% [markdown]
# # nombre = "Luis"
# edad = 23
# direccion = "Calle del Pez, 3"
#
# if nombre == "Luis":
#     print("Hola Luis")
#
# if edad < 18:
#     print(nombre + " es menor de edad")
#     print("Fin del programa")
#
# if edad < 18:
#     print(nombre + " es menor de edad")
# print("Fin del programa")

# %%
print("Hola " + nombre)
# Out:
# Hola Luis

# %%
if
