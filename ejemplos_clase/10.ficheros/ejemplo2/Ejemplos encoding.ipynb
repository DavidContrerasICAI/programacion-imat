# %%
# !dir
# Out:
#  El volumen de la unidad C es C_Win11
#  El n£mero de serie del volumen es: F8E6-2868
#
#  Directorio de C:\Users\stic\Downloads
#
# 21/11/2023  09:08    <DIR>          .
# 01/09/2023  09:13    <DIR>          ..
# 21/11/2023  09:08    <DIR>          .ipynb_checkpoints
# 21/11/2023  09:08           793.589 palabras.txt
# 21/11/2023  09:08            36.595 Tema 10. Ficheros.ipynb
# 21/11/2023  09:06                72 Untitled.ipynb
#                3 archivos        830.256 bytes
#                3 dirs  332.952.416.256 bytes libres

# %%
# !type palabras.txt
# Out:
# a
# aaronita
# aarÃ³nico
# aba
# ababa
# ababillarse
# ababol
# abacal
# abacalero
# abacero
# abacerÃ­a
# abacial
# abacora
# abacorar
# abacÃ¡
# abad
# abada
# abadejo
# abadengo
# abadernar
# abadesa
# abadiado
# abadiato
# abadÃ­
# abadÃ­a
# abajadero
# abajamiento
# abajar
# abajera
# abajeÃ±o
# abajo
# abalada
# abalanzar
# abalar
# abalaustrado
# abaldonadamente
# abaldonamiento
# abaldonar
# abaleador
# abaleadura
# abalear
# abaleo
# abalizamiento
# abalizar
# aballar
# aballestar
# abalorio
# abaluartar
# abanador
# abanar
# abancalar
# abanderado
# abanderamiento
# abanderar
# abanderizador
# abanderizar
# abandonado
# abandonamiento
# abandonar
# abandonismo
# abandonista
# abandono
# abanear
# abanicar
# abanicazo
# abanico
# abanillo
# abanino
# abaniqueo
# abaniquero
# abaniquerÃ­a
# abano
# abanto
# abarajar
# abaratamiento
# abaratar
# abaraÃ±ar
# abarbechar
# abarbetar
# abarca
# abarcable
# abarcado
# abarcador
# abarcadura
# abarcamiento
# abarcar
# abarcuzar
# ...

# %%
# !dir
# Out:
#  El volumen de la unidad C es C_Win11
#  El n£mero de serie del volumen es: F8E6-2868
#
#  Directorio de C:\Users\stic\Downloads
#
# 21/11/2023  09:29    <DIR>          .
# 01/09/2023  09:13    <DIR>          ..
# 21/11/2023  09:08    <DIR>          .ipynb_checkpoints
# 21/11/2023  09:08            36.595 Tema 10. Ficheros.ipynb
# 21/11/2023  09:28         1.716.761 Untitled.ipynb
#                2 archivos      1.753.356 bytes
#                3 dirs  332.769.550.336 bytes libres

# %%
fichero = open("data\\palabras.txt", "r", encoding = "utf-8")
contenido = fichero.read()
print(contenido)
fichero.close()
# Out:
# a
# aaronita
# aarónico
# aba
# ababa
# ababillarse
# ababol
# abacal
# abacalero
# abacero
# abacería
# abacial
# abacora
# abacorar
# abacá
# abad
# abada
# abadejo
# abadengo
# abadernar
# abadesa
# abadiado
# abadiato
# abadí
# abadía
# abajadero
# abajamiento
# abajar
# abajera
# abajeño
# abajo
# abalada
# abalanzar
# abalar
# abalaustrado
# abaldonadamente
# abaldonamiento
# abaldonar
# abaleador
# abaleadura
# abalear
# abaleo
# abalizamiento
# abalizar
# aballar
# aballestar
# abalorio
# abaluartar
# abanador
# abanar
# abancalar
# abanderado
# abanderamiento
# abanderar
# abanderizador
# abanderizar
# abandonado
# abandonamiento
# abandonar
# abandonismo
# abandonista
# abandono
# abanear
# abanicar
# abanicazo
# abanico
# abanillo
# abanino
# abaniqueo
# abaniquero
# abaniquería
# abano
# abanto
# abarajar
# abaratamiento
# abaratar
# abarañar
# abarbechar
# abarbetar
# abarca
# abarcable
# abarcado
# abarcador
# abarcadura
# abarcamiento
# abarcar
# abarcuzar
# abarcón
# ...
