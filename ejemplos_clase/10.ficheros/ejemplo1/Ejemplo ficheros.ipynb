# %%
s = "     Luis Fernando Gómez \n  \t    "

# %%
s
# Out:
# '     Luis   \n  \t    '

# %%
s2 = s.strip()
print(s2)
print(s)
# Out:
# Luis
#      Luis

# %%
s.lstrip()
# Out:
# 'Luis   \n  \t    '

# %%
s.rstrip()
# Out:
# '     Luis'

# %%
s2 = s.replace(" ", "")
print(s2)
# Out:
# Luis

# %%
"hola, manuel, 22".split(", ")
# Out:
# ['hola', 'manuel', '22']

# %%
def x(funcion):
