# %%
import matplotlib.pyplot as plt

asignaturas = ["Cálculo", "Probabilidad", "Programación", "Álgebra"]
notas_medias = [7.8, 6.5, 8.2, 7.1]

plt.figure()
plt.bar(asignaturas, notas_medias)
plt.title("Notas medias por asignatura")
plt.ylabel("Nota media")
plt.ylim(0, 10)

plt.show()
