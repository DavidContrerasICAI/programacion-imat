# %%
lista = [1234, True, "abcd"]

# %%
i = 0
while i < len(lista):
    print(lista[i])
    i += 1
# Out:
# 1234
# True
# abcd

# %%
lista
# Out:
# [1234, True, 'abcd']

# %%
type(lista)
# Out:
# list

# %%
lista[::-1]
# Out:
# ['abcd', True, 1234]

# %%
s = "abcd123"
s[5]
# Out:
# '2'

# %%
lista[1]
# Out:
# True

# %%
personas = ["Luis", "Maria", "Ana"]
palabras = ["rosal"]
numeros = [1, 4, 77676, 12]

# %%
lista
# Out:
# []

# %%
cadena = ""

# %%
cadena += "abcd3"
cadena
# Out:
# 'abcd3'

# %%
s = "abc"
s.lower()
# Out:
# 'abc'

# %%
#do-while
lista = []
a = input("Dime la palabra:" )
while a != "FIN":
    lista.append(a)
    a = input("Dime la palabra:" )
lista
# Out:
# Dime la palabra: fin
# Dime la palabra: rosal
# Dime la palabra: mesa
# Dime la palabra: libro
# Dime la palabra: FIN
# ['fin', 'rosal', 'mesa', 'libro']

# %%
#while
SEPARADOR = "FIN"
lista = []
a = ""
while a.upper() != SEPARADOR:
    a = input("Dime la palabra:" )
    lista.append(a)
lista.remove(SEPARADOR)
lista
# Out:
# Dime la palabra: fin
# Dime la palabra: fin
# Dime la palabra: Fin
# Dime la palabra: FiN
# Dime la palabra: FIN
# ['fin', 'fin', 'Fin', 'FiN']

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
amigo_a_borrar = "Manuel"
if amigo_a_borrar in amigos:
    amigos.remove(amigo_a_borrar)

# %%
amigos
# Out:
# ['Luis', 'Ana', 'Marta', 'Pepe']

# %%
"a" in "nsasaa"
# Out:
# True

# %%
"Luis" in amigos
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
cadena = "abcd"
for letra in cadena:
    print(letra)
# Out:
# a
# b
# c
# d

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
for amigo in amigos:
    print(amigo)
# Out:
# Luis
# Ana
# Marta
# Pepe

# %%
amigos.sort()

# %%
amigos
# Out:
# ['Ana', 'Luis', 'Marta', 'Pepe']

# %%
sorted(amigos)
# Out:
# ['Ana', 'Luis', 'Marta', 'Pepe']

# %%
sorted("dshsahdjahdius")
# Out:
# ['a', 'a', 'd', 'd', 'd', 'h', 'h', 'h', 'i', 'j', 's', 's', 's', 'u']

# %%
nombre = "Luis"
list(nombre)
# Out:
# ['L', 'u', 'i', 's']

# %%
range(1, 10, 2)
# Out:
# range(1, 10, 2)

# %%
range(10)
# Out:
# range(0, 10)

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
for i in range(len(amigos)):
    print(i+1, amigos[i])
# Out:
# 1 Luis
# 2 Ana
# 3 Marta
# 4 Pepe

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
for amigo in amigos:
    print(amigo)
# Out:
# Luis
# Ana
# Marta
# Pepe

# %%
if "Ana" in amigos:
    print(amigos.index("Ana"))
# Out:
# 1

# %%
type(amigos)
# Out:
# list

# %% [markdown]
# ![image.png](attachment:9432dd9c-fe0c-4878-8ed6-9a01e7ab6332.png)

# %%
amigos.pop()
# Out:
# 'Pepe'

# %%
amigos.pop(1)
# Out:
# 'Ana'

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
amigo_pop = amigos.pop()
amigos
# Out:
# ['Luis', 'Ana', 'Marta']

# %%
amigo_pop
# Out:
# 'Pepe'

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]
amigos[len(amigos)-1]
# Out:
# 'Pepe'

# %%
amigos.pop()
amigos
# Out:
# ['Luis']

# %%
nombre = "luis"

# %%
nombre[0] = "L"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 nombre[0] = "L"
#
# TypeError: 'str' object does not support item assignment

# %%
nombre = "luis"
nombre = nombre[0].upper() + nombre[1:]
nombre
# Out:
# 'Luis'

# %%
lista = ["l", "u", "i", "s"]
lista[0] = "L"

# %%
amigos = ["Luis", "Ana", "Marta", "Pepe"]

# %%
amigos[0] = "Manuel"
amigos
# Out:
# ['Manuel', 'Ana', 'Marta', 'Pepe']

# %% [markdown]
# # Matrices: listas de 2 dimensiones

# %%
cantantes = ["Adele", "Ed Sheeran", "Beyoncé", "Bruno Mars", "Billie Eilish"]
print("CANTANTES")
for cantante in cantantes:
    print(cantante)

canciones_adele = ["Someone Like You", "Hello", "Rolling in the Deep", "Set Fire to the Rain", 
                        "Easy On Me"]
canciones_ed = ["Shape of You", "Perfect", "Thinking Out Loud", "Castle on the Hill", "Bad Habits"]

todas_canciones = [canciones_adele, canciones_ed]

print("CANCIONES")
for canciones in todas_canciones:
    print(canciones)
# Out:
# CANTANTES
# Adele
# Ed Sheeran
# Beyoncé
# Bruno Mars
# Billie Eilish
# CANCIONES
# ['Someone Like You', 'Hello', 'Rolling in the Deep', 'Set Fire to the Rain', 'Easy On Me']
# ['Shape of You', 'Perfect', 'Thinking Out Loud', 'Castle on the Hill', 'Bad Habits']

# %%
for i in range(len(todas_canciones)):
    print(cantantes[i])
    print("=" * 30)
    canciones_de_un_cantante = todas_canciones[i]
    for cancion in canciones_de_un_cantante:
        print(" -", cancion)
    print()
# Out:
# Adele
# ...
#  - Someone Like You
#  - Hello
#  - Rolling in the Deep
#  - Set Fire to the Rain
#  - Easy On Me
#
# Ed Sheeran
# ...
#  - Shape of You
#  - Perfect
#  - Thinking Out Loud
#  - Castle on the Hill
#  - Bad Habits
